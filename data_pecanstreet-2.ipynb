# %% [markdown]
# # Step 1: importing libraries

# %%
# Load the all libraries we need for ML 
# %matplotlib inline

import os
import numpy as np
import pandas as pd
import keras
import tensorflow as tf
import matplotlib.pyplot as plt
import sklearn.preprocessing
from sklearn.metrics import r2_score
from keras.layers import Dense,Dropout,SimpleRNN,LSTM
from keras.models import Sequential
import seaborn as sns

#check all the files in the input dataset
#os.chdir("fifteen_minute_data_newyork.csv")
df = pd.read_csv('fifteen_minute_data_newyork.csv')

#print(os.listdir("fifteen_minute_data_newyork.csv"))

# Get the name of the directory containing the files
# Read data from file 'filename.csv' 
pd.read_csv('fifteen_minute_data_newyork.csv', delimiter=',',skiprows=1)

article_read = pd.read_csv(
    'fifteen_minute_data_newyork.csv', 
    delimiter=',', 
)

#Let's use datetime(2012-10-01 12:00:00,...) as index instead of numbers(0,1,...)
#This will be helpful for further data analysis as we are dealing with time series data
#df = pd.read_csv(fpath, index_col='local_15min', parse_dates=['local_15min'])
#df.head()

df= article_read[article_read['dataid']==3000][['local_15min', 'solar', 'dataid', 'grid', 'car1']] #shows only slected colomns 

df.head()
#article_read.count()


# Get the name of the directory containing the files
# Read data from file 'filename.csv' 
# (in the same directory that your python process is based), format: data/test_file.csv
#data = pd.read_csv(Users/valeriamaksimovich/'fifteen_minute_data_newyork.csv')
#pd.read_csv('15minute_data_newyork.csv')
#print(data.head(10))



#import os # Import the os module
#cwd = os.getcwd() # Get the current working directory
#print("Current working directory: {0}".format(cwd)) # Print the current working directory
# Out:
#                 local_15min  solar  dataid   grid   car1
# 56   2019-06-24 14:45:00-05  1.148    3000 -1.892  0.002
# 57   2019-06-24 14:30:00-05  1.345    3000 -2.154  0.002
# 58   2019-06-24 14:15:00-05  1.204    3000 -1.869  0.002
# 59   2019-06-24 14:00:00-05  0.968    3000 -1.617  0.002
# 171  2019-06-24 15:15:00-05  1.044    3000 -1.647  0.002

# %% [markdown]
# # Information about the dataset

# %%
print("="*50)
print("First Five Rows ","\n")
print(article_read.head(2),"\n")

print("="*50)
print("Information About Dataset","\n")
print(article_read.info(),"\n")

print("="*50)
print("Describe the Dataset ","\n")
print(article_read.describe(),"\n")

print("="*50)
print("Null Values t ","\n")
print(article_read.isnull().sum(),"\n")
# Out:
# ==================================================
# First Five Rows
#
#    dataid             local_15min  air1  air2  air3  airwindowunit1  \
# 0    4550  2019-06-24 14:45:00-05   NaN   NaN   NaN             NaN
# 1    4550  2019-06-24 14:30:00-05   NaN   NaN   NaN             NaN
#
#    aquarium1  bathroom1  bathroom2  bedroom1  ...  sprinkler1  sumppump1  \
# 0        NaN        NaN        NaN       NaN  ...         NaN        NaN
# 1        NaN        NaN        NaN       NaN  ...         NaN        NaN
#
#    utilityroom1  venthood1  waterheater1  waterheater2  wellpump1  \
# 0           NaN        NaN           NaN           NaN        0.0
# 1           NaN        NaN           NaN           NaN        0.0
#
#    winecooler1    leg1v    leg2v
# 0          NaN  120.625  120.750
# 1          NaN  120.456  120.558
#
# [2 rows x 79 columns]
#
# ==================================================
# Information About Dataset
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 441599 entries, 0 to 441598
# Data columns (total 79 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   dataid                441599 non-null  int64
#  1   local_15min           441599 non-null  object
#  2   air1                  190235 non-null  float64
#  3   air2                  35327 non-null   float64
#  4   air3                  0 non-null       float64
#  5   airwindowunit1        17664 non-null   float64
#  6   aquarium1             0 non-null       float64
#  7   bathroom1             70656 non-null   float64
#  8   bathroom2             0 non-null       float64
#  9   bedroom1              70656 non-null   float64
#  10  bedroom2              0 non-null       float64
#  11  bedroom3              0 non-null       float64
#  12  bedroom4              0 non-null       float64
#  13  bedroom5              0 non-null       float64
#  14  battery1              0 non-null       float64
#  15  car1                  88283 non-null   float64
#  16  car2                  8276 non-null    float64
#  17  circpump1             70656 non-null   float64
#  18  clotheswasher1        282624 non-null  float64
#  19  clotheswasher_dryg1   52991 non-null   float64
#  20  diningroom1           17664 non-null   float64
#  21  diningroom2           0 non-null       float64
#  22  dishwasher1           211968 non-null  float64
#  23  disposal1             17664 non-null   float64
#  24  drye1                 300288 non-null  float64
#  25  dryg1                 0 non-null       float64
#  26  freezer1              123647 non-null  float64
#  27  furnace1              207900 non-null  float64
#  28  furnace2              17664 non-null   float64
#  29  garage1               123647 non-null  float64
#  30  garage2               0 non-null       float64
#  31  grid                  441599 non-null  float64
#  32  heater1               194304 non-null  float64
#  33  heater2               35328 non-null   float64
#  34  heater3               17664 non-null   float64
#  35  housefan1             17664 non-null   float64
#  36  icemaker1             0 non-null       float64
#  37  jacuzzi1              35328 non-null   float64
#  38  kitchen1              35328 non-null   float64
#  39  kitchen2              0 non-null       float64
#  40  kitchenapp1           317951 non-null  float64
#  41  kitchenapp2           211967 non-null  float64
#  42  lights_plugs1         88320 non-null   float64
#  43  lights_plugs2         52992 non-null   float64
#  44  lights_plugs3         35328 non-null   float64
#  45  lights_plugs4         17664 non-null   float64
#  46  lights_plugs5         0 non-null       float64
#  47  lights_plugs6         0 non-null       float64
#  48  livingroom1           105984 non-null  float64
#  49  livingroom2           0 non-null       float64
#  50  microwave1            52992 non-null   float64
#  51  office1               17664 non-null   float64
#  52  outsidelights_plugs1  0 non-null       float64
#  53  outsidelights_plugs2  0 non-null       float64
#  54  oven1                 105984 non-null  float64
#  55  oven2                 0 non-null       float64
#  56  pool1                 0 non-null       float64
#  57  pool2                 0 non-null       float64
#  58  poollight1            0 non-null       float64
#  59  poolpump1             0 non-null       float64
#  60  pump1                 88320 non-null   float64
#  61  range1                176640 non-null  float64
#  62  refrigerator1         211968 non-null  float64
#  63  refrigerator2         0 non-null       float64
#  64  security1             0 non-null       float64
#  65  sewerpump1            17664 non-null   float64
#  66  shed1                 0 non-null       float64
#  67  solar                 247295 non-null  float64
#  68  solar2                17628 non-null   float64
#  69  sprinkler1            0 non-null       float64
#  70  sumppump1             17664 non-null   float64
#  71  utilityroom1          35328 non-null   float64
#  72  venthood1             35328 non-null   float64
#  73  waterheater1          176639 non-null  float64
#  74  waterheater2          0 non-null       float64
#  75  wellpump1             158975 non-null  float64
#  76  winecooler1           0 non-null       float64
#  77  leg1v                 441599 non-null  float64
#  78  leg2v                 441599 non-null  float64
# dtypes: float64(77), int64(1), object(1)
# memory usage: 266.2+ MB
# None
#
# ==================================================
# Describe the Dataset
#
#               dataid           air1          air2  air3  airwindowunit1  \
# count  441599.000000  190235.000000  35327.000000   0.0    17664.000000
# mean     3100.766961       0.146473      0.032976   NaN        0.000488
# std      2255.762220       0.435807      0.185626   NaN        0.003345
# min        27.000000      -0.006000     -0.003000   NaN       -0.002000
# 25%      1222.000000       0.000000      0.000000   NaN        0.000000
# 50%      3000.000000       0.006000      0.006000   NaN        0.000000
# 75%      4550.000000       0.043000      0.028000   NaN        0.001000
# max      9053.000000       3.047000      4.036000   NaN        0.092000
#
#        aquarium1     bathroom1  bathroom2      bedroom1  bedroom2  ...  \
# count        0.0  70656.000000        0.0  70656.000000       0.0  ...
# mean         NaN      0.004370        NaN      0.029447       NaN  ...
# std          NaN      0.014576        NaN      0.113602       NaN  ...
# min          NaN     -0.001000        NaN     -0.003000       NaN  ...
# 25%          NaN      0.001000        NaN      0.003000       NaN  ...
# 50%          NaN      0.001000        NaN      0.005000       NaN  ...
# 75%          NaN      0.001000        NaN      0.014000       NaN  ...
# max          NaN      0.179000        NaN      1.437000       NaN  ...
#
#        sprinkler1     sumppump1  utilityroom1     venthood1   waterheater1  \
# count         0.0  17664.000000  35328.000000  35328.000000  176639.000000
# mean          NaN      0.003936      0.202180      0.008533       0.200858
# std           NaN      0.017721      0.135203      0.037347       0.628078
# min           NaN     -0.002000     -0.002000      0.000000      -0.024000
# 25%           NaN      0.000000      0.091000      0.001000       0.000000
# 50%           NaN      0.000000      0.149000      0.003000       0.001000
# 75%           NaN      0.000000      0.287000      0.005000       0.003000
# max           NaN      0.496000      0.921000      0.621000      13.099000
#
#        waterheater2      wellpump1  winecooler1          leg1v          leg2v
# count           0.0  158975.000000          0.0  441599.000000  441599.000000
# mean            NaN       0.019322          NaN     121.769197     121.722828
# std             NaN       0.072704          NaN       2.665591       2.636105
# min             NaN      -0.014000          NaN       0.108000       0.107000
# 25%             NaN       0.000000          NaN     120.748000     120.764000
# 50%             NaN       0.000000          NaN     122.067000     122.001000
# 75%             NaN       0.002000          NaN     122.927000     122.837000
# max             NaN       1.176000          NaN     130.298000     130.310000
#
# [8 rows x 78 columns]
#
# ==================================================
# Null Values t
#
# dataid               0
# local_15min          0
# air1            251364
# air2            406272
# air3            441599
#                  ...
# waterheater2    441599
# wellpump1       282624
# winecooler1     441599
# leg1v                0
# leg2v                0
# Length: 79, dtype: int64

# %%
print("="*50)
print("First Five Rows ","\n")
print(df.head(2),"\n")

print("="*50)
print("Information About Dataset","\n")
print(df.info(),"\n")

print("="*50)
print("Describe the Dataset ","\n")
print(df.describe(),"\n")

print("="*50)
print("Null Values t ","\n")
print(df.isnull().sum(),"\n")
# Out:
# ==================================================
# First Five Rows
#
#                local_15min  solar  dataid   grid   car1
# 56  2019-06-24 14:45:00-05  1.148    3000 -1.892  0.002
# 57  2019-06-24 14:30:00-05  1.345    3000 -2.154  0.002
#
# ==================================================
# Information About Dataset
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17664 entries, 56 to 441554
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   local_15min  17664 non-null  object
#  1   solar        17664 non-null  float64
#  2   dataid       17664 non-null  int64
#  3   grid         17664 non-null  float64
#  4   car1         17628 non-null  float64
# dtypes: float64(3), int64(1), object(1)
# memory usage: 828.0+ KB
# None
#
# ==================================================
# Describe the Dataset
#
#               solar   dataid          grid          car1
# count  17664.000000  17664.0  17664.000000  17628.000000
# mean       0.532757   3000.0     -0.039476      0.133326
# std        0.808519      0.0      1.957045      0.679366
# min        0.000000   3000.0     -5.621000      0.002000
# 25%        0.000000   3000.0     -0.620000      0.002000
# 50%        0.043000   3000.0      0.417000      0.002000
# 75%        0.813000   3000.0      0.716000      0.002000
# max        3.010000   3000.0      7.384000      3.872000
#
# ==================================================
# Null Values t
#
# local_15min     0
# solar           0
# dataid          0
# grid            0
# car1           36
# dtype: int64

# %% [markdown]
# # Separating the time (local_15min) column
# taken from https://www.youtube.com/watch?v=rAYFuFNOCic and
# https://soumilshah1995.blogspot.com/2019/08/project-data-analysis-and.html

# %%
df['New_date'] = pd.to_datetime(df['local_15min']).dt.date
df['New_time'] = pd.to_datetime(df['local_15min']).dt.time
df['Month'] = pd.to_datetime(df['local_15min']).dt.month
df['Year'] = pd.to_datetime(df['local_15min']).dt.year
df['Week'] = pd.to_datetime(df['local_15min']).dt.week
df['Day'] = pd.to_datetime(df['local_15min']).dt.day_name()

df.head(2)
# Out:
# /Users/valeriamaksimovich/opt/anaconda3/envs/tensorflow_env/lib/python3.6/site-packages/ipykernel_launcher.py:5: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   """
#                local_15min  solar  dataid   grid   car1    New_date  New_time  \
# 56  2019-06-24 14:45:00-05  1.148    3000 -1.892  0.002  2019-06-24  14:45:00
# 57  2019-06-24 14:30:00-05  1.345    3000 -2.154  0.002  2019-06-24  14:30:00
#
#     Month  Year  Week     Day
# 56      6  2019    26  Monday
# 57      6  2019    26  Monday

# %%
#df.set_index(df['local_15min']).head(2)

df.set_index(df['New_date']).head(2)
# Out:
#                        local_15min  solar  dataid   grid   car1    New_date  \
# New_date
# 2019-06-24  2019-06-24 14:45:00-05  1.148    3000 -1.892  0.002  2019-06-24
# 2019-06-24  2019-06-24 14:30:00-05  1.345    3000 -2.154  0.002  2019-06-24
#
#             New_time  Month  Year  Week     Day
# New_date
# 2019-06-24  14:45:00      6  2019    26  Monday
# 2019-06-24  14:30:00      6  2019    26  Monday

# %%
df['Month'].unique()
# Out:
# array([ 6,  7,  8,  5,  9, 10])

# %% [markdown]
# # What was max and min energy consumption in june in MW?

# %%
df[df['Month']== 6]['grid'].max() #I guess its kW
# Out:
# 5.113

# %%
df[df['Month']== 6]['grid'].min()
# Out:
# -5.291

# %%
df[df['Month']== 6]['grid'].mean()
# Out:
# -0.23882534722222223

# %%
sns.distplot(df['grid'])

plt.title('Energy Distribution')

sns.set(rc={'figure.figsize':(19,8)})
# Out:
# /Users/valeriamaksimovich/opt/anaconda3/envs/tensorflow_env/lib/python3.6/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
fig = plt.figure()
ax1 = fig.add_subplot(111)

sns.lineplot(x= df['New_time'],y= df['grid'], data=df)
plt.title("Energy Consumption vs Time ")
plt.xlabel("Time")
plt.grid(True, alpha=1)
plt.legend()

for label in ax1.xaxis.get_ticklabels():
    label.set_rotation(90)
    
    
#sns.set(rc={'figure.figsize':(19,8)})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-315-af779187307f> in <module>
#       2 ax1 = fig.add_subplot(111)
#       3
# ----> 4 sns.lineplot(x= df['New_time'],y= df['grid'], data=df)
#       5 plt.title("Energy Consumption vs Time ")
#       6 plt.xlabel("Time")
#
# ~/opt/anaconda3/envs/tensorflow_env/lib/python3.6/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~/opt/anaconda3/envs/tensorflow_env/lib/python3.6/site-packages/seaborn/relational.py in lineplot(x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, units, estimator, ci, n_boot, seed, sort, err_style, err_kws, legend, ax, **kwargs)
#     701     p._attach(ax)
#     702
# --> 703     p.plot(ax, kwargs)
#     704     return ax
#     705
#
# ~/opt/anaconda3/envs/tensorflow_env/lib/python3.6/site-packages/seaborn/relational.py in plot(self, ax, kws)
#     527                     ax.plot(x[rows], y[rows], **kws)
#     528             else:
# --> 529                 line, = ax.plot(x, y, **kws)
#     530
#     531             # --- Draw the confidence intervals
#
# ~/opt/anaconda3/envs/tensorflow_env/lib/python3.6/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1743         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1744         for line in lines:
# -> 1745             self.add_line(line)
#    1746         self._request_autoscale_view(scalex=scalex, scaley=scaley)
#    1747         return lines
#
# ~/opt/anaconda3/envs/tensorflow_env/lib/python3.6/site-packages/matplotlib/axes/_base.py in add_line(self, line)
#    1962             line.set_clip_path(self.patch)
#    1963
# -> 1964         self._update_line_limits(line)
#    1965         if not line.get_label():
#    1966             line.set_label('_line%d' % len(self.lines))
#
# ~/opt/anaconda3/envs/tensorflow_env/lib/python3.6/site-packages/matplotlib/axes/_base.py in _update_line_limits(self, line)
#    1984         Figures out the data limit of the given line, updating self.dataLim.
#    1985         """
# -> 1986         path = line.get_path()
#    1987         if path.vertices.size == 0:
#    1988             return
#
# ~/opt/anaconda3/envs/tensorflow_env/lib/python3.6/site-packages/matplotlib/lines.py in get_path(self)
#    1009         """
#    1010         if self._invalidy or self._invalidx:
# -> 1011             self.recache()
#    1012         return self._path
#    1013
#
# ~/opt/anaconda3/envs/tensorflow_env/lib/python3.6/site-packages/matplotlib/lines.py in recache(self, always)
#     651         if always or self._invalidx:
#     652             xconv = self.convert_xunits(self._xorig)
# --> 653             x = _to_unmasked_float_array(xconv).ravel()
#     654         else:
#     655             x = self._x
#
# ~/opt/anaconda3/envs/tensorflow_env/lib/python3.6/site-packages/matplotlib/cbook/__init__.py in _to_unmasked_float_array(x)
#    1287         return np.ma.asarray(x, float).filled(np.nan)
#    1288     else:
# -> 1289         return np.asarray(x, float)
#    1290
#    1291
#
# ~/opt/anaconda3/envs/tensorflow_env/lib/python3.6/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order)
#      81
#      82     """
# ---> 83     return array(a, dtype, copy=False, order=order)
#      84
#      85
#
# TypeError: float() argument must be a string or a number, not 'datetime.time'

# %%
sns.lineplot(x= df['Month'], y= df['grid'], data=df)
              
sns.set(rc={'figure.figsize':(19,8)})

# %%
df[df['Month']== 9]['grid'].plot.line()


sns.set(rc={'figure.figsize':(19,8)})

# %%
sns.jointplot(x= df['Month'], 
              y= df['solar'], 
              data= df,
              kind= 'kde')

sns.set(rc={'figure.figsize':(19,8)})

# %%
sns.lineplot(x= df['New_date'], y= df['car1'], data= df)

sns.set(rc={'figure.figsize':(19,8)})

# %% [markdown]
# # Extracting data on a date range

# %%
df['New_date'].describe()
# Out:
# count          17664
# unique           184
# top       2019-05-04
# freq              96
# Name: New_date, dtype: object

# %%
df['New_date'].unique()
# Out:
# array([datetime.date(2019, 6, 24), datetime.date(2019, 6, 29),
#        datetime.date(2019, 6, 30), datetime.date(2019, 6, 25),
#        datetime.date(2019, 6, 26), datetime.date(2019, 6, 27),
#        datetime.date(2019, 6, 28), datetime.date(2019, 7, 5),
#        datetime.date(2019, 7, 1), datetime.date(2019, 7, 2),
#        datetime.date(2019, 7, 3), datetime.date(2019, 7, 4),
#        datetime.date(2019, 7, 10), datetime.date(2019, 7, 6),
#        datetime.date(2019, 7, 7), datetime.date(2019, 7, 8),
#        datetime.date(2019, 7, 9), datetime.date(2019, 7, 11),
#        datetime.date(2019, 7, 15), datetime.date(2019, 7, 12),
#        datetime.date(2019, 7, 13), datetime.date(2019, 7, 14),
#        datetime.date(2019, 7, 16), datetime.date(2019, 7, 20),
#        datetime.date(2019, 7, 17), datetime.date(2019, 7, 18),
#        datetime.date(2019, 7, 21), datetime.date(2019, 7, 19),
#        datetime.date(2019, 7, 25), datetime.date(2019, 7, 22),
#        datetime.date(2019, 7, 23), datetime.date(2019, 7, 24),
#        datetime.date(2019, 7, 26), datetime.date(2019, 8, 14),
#        datetime.date(2019, 7, 30), datetime.date(2019, 7, 27),
#        datetime.date(2019, 7, 28), datetime.date(2019, 7, 31),
#        datetime.date(2019, 7, 29), datetime.date(2019, 8, 4),
#        datetime.date(2019, 8, 1), datetime.date(2019, 8, 2),
#        datetime.date(2019, 8, 5), datetime.date(2019, 8, 3),
#        datetime.date(2019, 8, 7), datetime.date(2019, 8, 8),
#        datetime.date(2019, 8, 6), datetime.date(2019, 5, 6),
#        datetime.date(2019, 8, 12), datetime.date(2019, 8, 9),
#        datetime.date(2019, 8, 10), datetime.date(2019, 8, 11),
#        datetime.date(2019, 5, 3), datetime.date(2019, 5, 1),
#        datetime.date(2019, 5, 2), datetime.date(2019, 5, 4),
#        datetime.date(2019, 5, 5), datetime.date(2019, 8, 13),
#        datetime.date(2019, 5, 8), datetime.date(2019, 5, 7),
#        datetime.date(2019, 5, 9), datetime.date(2019, 5, 10),
#        datetime.date(2019, 5, 11), datetime.date(2019, 5, 12),
#        datetime.date(2019, 5, 13), datetime.date(2019, 5, 15),
#        datetime.date(2019, 5, 14), datetime.date(2019, 5, 16),
#        datetime.date(2019, 5, 17), datetime.date(2019, 5, 19),
#        datetime.date(2019, 5, 20), datetime.date(2019, 5, 18),
#        datetime.date(2019, 6, 21), datetime.date(2019, 5, 21),
#        datetime.date(2019, 5, 22), datetime.date(2019, 5, 23),
#        datetime.date(2019, 5, 26), datetime.date(2019, 5, 29),
#        datetime.date(2019, 5, 24), datetime.date(2019, 6, 22),
#        datetime.date(2019, 5, 25), datetime.date(2019, 5, 27),
#        datetime.date(2019, 5, 28), datetime.date(2019, 5, 31),
#        datetime.date(2019, 5, 30), datetime.date(2019, 6, 1),
#        datetime.date(2019, 6, 2), datetime.date(2019, 6, 3),
#        datetime.date(2019, 6, 9), datetime.date(2019, 6, 4),
#        datetime.date(2019, 6, 5), datetime.date(2019, 6, 6),
#        datetime.date(2019, 6, 7), datetime.date(2019, 6, 8),
#        datetime.date(2019, 6, 11), datetime.date(2019, 6, 10),
#        datetime.date(2019, 6, 12), datetime.date(2019, 6, 13),
#        datetime.date(2019, 6, 14), datetime.date(2019, 6, 15),
#        datetime.date(2019, 6, 16), datetime.date(2019, 6, 17),
#        datetime.date(2019, 6, 18), datetime.date(2019, 6, 19),
#        datetime.date(2019, 6, 20), datetime.date(2019, 6, 23),
#        datetime.date(2019, 8, 15), datetime.date(2019, 8, 16),
#        datetime.date(2019, 8, 17), datetime.date(2019, 8, 18),
#        datetime.date(2019, 8, 20), datetime.date(2019, 8, 19),
#        datetime.date(2019, 8, 21), datetime.date(2019, 8, 22),
#        datetime.date(2019, 8, 24), datetime.date(2019, 8, 23),
#        datetime.date(2019, 8, 25), datetime.date(2019, 8, 26),
#        datetime.date(2019, 8, 27), datetime.date(2019, 8, 28),
#        datetime.date(2019, 8, 29), datetime.date(2019, 9, 10),
#        datetime.date(2019, 8, 30), datetime.date(2019, 8, 31),
#        datetime.date(2019, 9, 1), datetime.date(2019, 9, 2),
#        datetime.date(2019, 9, 3), datetime.date(2019, 9, 4),
#        datetime.date(2019, 9, 5), datetime.date(2019, 9, 6),
#        datetime.date(2019, 9, 7), datetime.date(2019, 9, 8),
#        datetime.date(2019, 9, 9), datetime.date(2019, 9, 12),
#        datetime.date(2019, 9, 11), datetime.date(2019, 9, 13),
#        datetime.date(2019, 9, 14), datetime.date(2019, 9, 15),
#        datetime.date(2019, 9, 16), datetime.date(2019, 9, 17),
#        datetime.date(2019, 9, 18), datetime.date(2019, 9, 19),
#        datetime.date(2019, 9, 21), datetime.date(2019, 9, 20),
#        datetime.date(2019, 9, 22), datetime.date(2019, 9, 23),
#        datetime.date(2019, 9, 24), datetime.date(2019, 9, 25),
#        datetime.date(2019, 9, 26), datetime.date(2019, 10, 9),
#        datetime.date(2019, 9, 27), datetime.date(2019, 9, 28),
#        datetime.date(2019, 9, 30), datetime.date(2019, 9, 29),
#        datetime.date(2019, 10, 1), datetime.date(2019, 10, 2),
#        datetime.date(2019, 10, 3), datetime.date(2019, 10, 6),
#        datetime.date(2019, 10, 4), datetime.date(2019, 10, 5),
#        datetime.date(2019, 10, 7), datetime.date(2019, 10, 8),
#        datetime.date(2019, 10, 10), datetime.date(2019, 10, 11),
#        datetime.date(2019, 10, 12), datetime.date(2019, 10, 14),
#        datetime.date(2019, 10, 13), datetime.date(2019, 10, 15),
#        datetime.date(2019, 10, 16), datetime.date(2019, 10, 18),
#        datetime.date(2019, 10, 17), datetime.date(2019, 10, 19),
#        datetime.date(2019, 10, 26), datetime.date(2019, 10, 20),
#        datetime.date(2019, 10, 21), datetime.date(2019, 10, 22),
#        datetime.date(2019, 10, 23), datetime.date(2019, 10, 24),
#        datetime.date(2019, 10, 25), datetime.date(2019, 10, 27),
#        datetime.date(2019, 10, 28), datetime.date(2019, 10, 29),
#        datetime.date(2019, 10, 31), datetime.date(2019, 10, 30)],
#       dtype=object)

# %%
df.set_index(df['New_date']).head(2)
# Out:
#                        local_15min  solar  dataid   grid   car1    New_date  \
# New_date
# 2019-06-24  2019-06-24 14:45:00-05  1.148    3000 -1.892  0.002  2019-06-24
# 2019-06-24  2019-06-24 14:30:00-05  1.345    3000 -2.154  0.002  2019-06-24
#
#             New_time  Month  Year  Week  week     day     Day
# New_date
# 2019-06-24  14:45:00      6  2019    26    26  Monday  Monday
# 2019-06-24  14:30:00      6  2019    26    26  Monday  Monday

# %%
from matplotlib import style

fig = plt.figure()
ax1 = plt.subplot2grid((1,1), (0,0))

style.use('ggplot')

sns.lineplot(x=df["New_date"], y=df["grid"], data=df)
sns.set(rc={'figure.figsize':(19,8)})

plt.title("Energy consumption in the house 3000")
plt.xlabel("Date")
plt.ylabel("Energy in MW")
plt.grid(True)
plt.legend()

for label in ax1.xaxis.get_ticklabels():
    label.set_rotation(90)


plt.title("Energy Consumption in the house 3000")
# Out:
# No handles with labels found to put in legend.
# Text(0.5, 1.0, 'Energy Consumption in the house 3000')

# %%
from matplotlib import style


fig = plt.figure()

ax1= fig.add_subplot(311)
ax2= fig.add_subplot(312)
ax3= fig.add_subplot(313)


style.use('ggplot')

y_6 = [df['Month']== 6]['grid'].to_list()
x_6 = [df['Month']== 6]["New_date"].to_list()
ax1.plot(x_6,y_6, color="green", linewidth=1.7)


y_2005 = df[df['Month']== 7]["grid"].to_list()
x_2005 = df[df['Month']== 7]["New_date"].to_list()
ax2.plot(x_2005, y_2005, color="green", linewidth=1)


y_2006 = df[df['Month']== 8]["grid"].to_list()
x_2006 = df[df['Month']== 8]["New_date"].to_list()
ax3.plot(x_2006, y_2006, color="green", linewidth=1)


plt.rcParams["figure.figsize"] = (18,8)
plt.title("Energy consumptionnin")
plt.xlabel("Date")
plt.ylabel("Energy in MW")
plt.grid(True, alpha=1)
plt.legend()

for label in ax1.xaxis.get_ticklabels():
    label.set_rotation(90)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/envs/tensorflow_env/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'Month'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-265-5e771d1d6ba0> in <module>
#      11 style.use('ggplot')
#      12
# ---> 13 y_6 = [df['Month']== 6]['grid'].to_list()
#      14 x_6 = [df['Month']== 6]["New_date"].to_list()
#      15 ax1.plot(x_6,y_6, color="green", linewidth=1.7)
#
# ~/opt/anaconda3/envs/tensorflow_env/lib/python3.6/site-packages/pandas/core/series.py in __getitem__(self, key)
#     880
#     881         elif key_is_scalar:
# --> 882             return self._get_value(key)
#     883
#     884         if is_hashable(key):
#
# ~/opt/anaconda3/envs/tensorflow_env/lib/python3.6/site-packages/pandas/core/series.py in _get_value(self, label, takeable)
#     987
#     988         # Similar to Index.get_value, but we do not fall back to positional
# --> 989         loc = self.index.get_loc(label)
#     990         return self.index._get_values_for_loc(self, loc, label)
#     991
#
# ~/opt/anaconda3/envs/tensorflow_env/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'Month'

# %%
#df.loc['2019-07-10':'2019-08-10'] #1 month
# Out:
# Empty DataFrame
# Columns: [local_15min, solar, dataid, grid, car1, New_date, New_time, Month, Year]
# Index: []

# %%
#df = df[(df['local_15min'] > '2019-08-10') & (df['local_15min'] <= '2019-09-10')] ['grid']
        
#df.head(2)
# Out:
# 72491    0.727
# 72492    0.710
# Name: grid, dtype: float64

# %% [markdown]
# # PREDICTIONS

# %%
print("Dataset Size",df.shape )
# Out:
# Dataset Size (17664, 11)

# %%
TestData = df.tail(100)

Training_Set = df.iloc[:,0:1]

Training_Set = Training_Set[:-60]

# %%
print("Training Set Shape ", Training_Set.shape)
print("Test Set Shape ", TestData.shape)
# Out:
# Training Set Shape  (17604, 1)
# Test Set Shape  (100, 11)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
Training_Set = Training_Set.values
sc = MinMaxScaler(feature_range=(0, 1))
Train = sc.fit_transform(Training_Set)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-360-46db85ef43d1> in <module>
# ----> 1 Training_Set = Training_Set.values
#       2 sc = MinMaxScaler(feature_range=(0, 1))
#       3 Train = sc.fit_transform(Training_Set)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'values'

# %%
X_Train = []
Y_Train = []

# Range should be fromm 60 Values to END 
for i in range(60, Train.shape[0]):
    
    # X_Train 0-59 
    X_Train.append(Train[i-60:i])
    
    # Y Would be 60 th Value based on past 60 Values 
    Y_Train.append(Train[i])

# Convert into Numpy Array
X_Train = np.array(X_Train)
Y_Train = np.array(Y_Train)

print(X_Train.shape)
print(Y_Train.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-361-ff197b59c9a0> in <module>
#       3
#       4 # Range should be fromm 60 Values to END
# ----> 5 for i in range(60, Train.shape[0]):
#       6
#       7     # X_Train 0-59
#
# NameError: name 'Train' is not defined

# %%
# Shape should be Number of [Datapoints , Steps , 1 )
# we convert into 3-d Vector or #rd Dimesnsion
X_Train = np.reshape(X_Train, newshape=(X_Train.shape[0], X_Train.shape[1], 1))
X_Train.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-323-4b4ad81508b7> in <module>
#       1 # Shape should be Number of [Datapoints , Steps , 1 )
#       2 # we convert into 3-d Vector or #rd Dimesnsion
# ----> 3 X_Train = np.reshape(X_Train, newshape=(X_Train.shape[0], X_Train.shape[1], 1))
#       4 X_Train.shape
#
# AttributeError: 'list' object has no attribute 'shape'

# %%
regressor = Sequential()

# Adding the first LSTM layer and some Dropout regularisation
regressor.add(LSTM(units = 50, return_sequences = True, input_shape = (X_Train.shape[1], 1)))
regressor.add(Dropout(0.2))

# Adding a second LSTM layer and some Dropout regularisation
regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.2))

# Adding a third LSTM layer and some Dropout regularisation
regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.2))

# Adding a fourth LSTM layer and some Dropout regularisation
regressor.add(LSTM(units = 50))
regressor.add(Dropout(0.2))

# Adding the output layer
regressor.add(Dense(units = 1))

# Compiling the RNN
regressor.compile(optimizer = 'adam', loss = 'mean_squared_error')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-322-6962636c698d> in <module>
#       2
#       3 # Adding the first LSTM layer and some Dropout regularisation
# ----> 4 regressor.add(LSTM(units = 50, return_sequences = True, input_shape = (X_Train.shape[1], 1)))
#       5 regressor.add(Dropout(0.2))
#       6
#
# AttributeError: 'list' object has no attribute 'shape'

# %% [markdown]
# # Explanations
# **article_read** is this file: 'fifteen_minute_data_newyork.csv'
#
# **df_old** is used just to delete the first column (numbering) 0,1,2,3,4
#
# **df** is time and grid cinsumpton

# %%
#just all the data 

fpath='fifteen_minute_data_newyork.csv'

df=pd.read_csv(fpath)
df.head()
# Out:
#    dataid             local_15min   air1  air2  air3  airwindowunit1  \
# 0    4550  2019-06-24 14:45:00-05    NaN   NaN   NaN             NaN
# 1    4550  2019-06-24 14:30:00-05    NaN   NaN   NaN             NaN
# 2    4550  2019-06-24 14:15:00-05    NaN   NaN   NaN             NaN
# 3    4550  2019-06-24 14:00:00-05    NaN   NaN   NaN             NaN
# 4     558  2019-06-24 14:45:00-05  0.081   NaN   NaN             NaN
#
#    aquarium1  bathroom1  bathroom2  bedroom1  ...  sprinkler1  sumppump1  \
# 0        NaN        NaN        NaN       NaN  ...         NaN        NaN
# 1        NaN        NaN        NaN       NaN  ...         NaN        NaN
# 2        NaN        NaN        NaN       NaN  ...         NaN        NaN
# 3        NaN        NaN        NaN       NaN  ...         NaN        NaN
# 4        NaN        NaN        NaN       NaN  ...         NaN        NaN
#
#    utilityroom1  venthood1  waterheater1  waterheater2  wellpump1  \
# 0           NaN        NaN           NaN           NaN        0.0
# 1           NaN        NaN           NaN           NaN        0.0
# 2           NaN        NaN           NaN           NaN        0.0
# 3           NaN        NaN           NaN           NaN        0.0
# 4           NaN        NaN           NaN           NaN        NaN
#
#    winecooler1    leg1v    leg2v
# 0          NaN  120.625  120.750
# 1          NaN  120.456  120.558
# 2          NaN  120.513  120.629
# 3          NaN  121.567  121.638
# 4          NaN  120.390  120.388
#
# [5 rows x 79 columns]

# %%
#checking missing data
#df.isna().sum()

## df1 as an example data frame 
## col1 name of column for which you want to calculate the nan values
sum(pd.isnull(['grid']))
# Out:
# 0

# %%
#article_read.filter(regex = '914', axis = 1 ) 

article_read[article_read['dataid']==914][['dataid','local_15min', 'grid', 'car1', 'solar', 'solar2', 'battery1']] #filtering, counting the colomns: .isna().sum() 
#.hist() 

#article_read[['dataid', 'local_15min', 'grid', 'local_15min', 'grid', 'air1', 'air2', 'air3', 'waterheater2', 'wellpump1',]]
    
#(article_read[article_read['dataid']==914].isna().sum() # counting the colomns: .isna().sum() - identifying which things hve values
# Out:
#         dataid             local_15min   grid  car1  solar  solar2  battery1
# 100        914  2019-06-24 14:45:00-05 -3.311   NaN  3.831     NaN       NaN
# 101        914  2019-06-24 14:30:00-05 -2.354   NaN  2.971     NaN       NaN
# 102        914  2019-06-24 14:15:00-05 -2.126   NaN  2.582     NaN       NaN
# 103        914  2019-06-24 14:00:00-05 -2.418   NaN  2.783     NaN       NaN
# 208        914  2019-06-24 15:45:00-05 -2.019   NaN  2.488     NaN       NaN
# ...        ...                     ...    ...   ...    ...     ...       ...
# 441426     914  2019-10-31 22:00:00-05  0.623   NaN -0.002     NaN       NaN
# 441595     914  2019-10-31 23:45:00-05  0.360   NaN -0.003     NaN       NaN
# 441596     914  2019-10-31 23:30:00-05  0.548   NaN -0.003     NaN       NaN
# 441597     914  2019-10-31 23:15:00-05  0.539   NaN -0.003     NaN       NaN
# 441598     914  2019-10-31 23:00:00-05  0.341   NaN -0.003     NaN       NaN
#
# [17664 rows x 7 columns]

# %% [markdown]
# # Visualisation

# %%
df_old= pd.read_csv('fifteen_minute_data_newyork.csv', index_col='local_15min', parse_dates=['local_15min'])

df_old.head()
# Out:
#                            dataid   air1  air2  air3  airwindowunit1  \
# local_15min
# 2019-06-24 14:45:00-05:00    4550    NaN   NaN   NaN             NaN
# 2019-06-24 14:30:00-05:00    4550    NaN   NaN   NaN             NaN
# 2019-06-24 14:15:00-05:00    4550    NaN   NaN   NaN             NaN
# 2019-06-24 14:00:00-05:00    4550    NaN   NaN   NaN             NaN
# 2019-06-24 14:45:00-05:00     558  0.081   NaN   NaN             NaN
#
#                            aquarium1  bathroom1  bathroom2  bedroom1  \
# local_15min
# 2019-06-24 14:45:00-05:00        NaN        NaN        NaN       NaN
# 2019-06-24 14:30:00-05:00        NaN        NaN        NaN       NaN
# 2019-06-24 14:15:00-05:00        NaN        NaN        NaN       NaN
# 2019-06-24 14:00:00-05:00        NaN        NaN        NaN       NaN
# 2019-06-24 14:45:00-05:00        NaN        NaN        NaN       NaN
#
#                            bedroom2  ...  sprinkler1  sumppump1  utilityroom1  \
# local_15min                          ...
# 2019-06-24 14:45:00-05:00       NaN  ...         NaN        NaN           NaN
# 2019-06-24 14:30:00-05:00       NaN  ...         NaN        NaN           NaN
# 2019-06-24 14:15:00-05:00       NaN  ...         NaN        NaN           NaN
# 2019-06-24 14:00:00-05:00       NaN  ...         NaN        NaN           NaN
# 2019-06-24 14:45:00-05:00       NaN  ...         NaN        NaN           NaN
#
#                            venthood1  waterheater1  waterheater2  wellpump1  \
# local_15min
# 2019-06-24 14:45:00-05:00        NaN           NaN           NaN        0.0
# 2019-06-24 14:30:00-05:00        NaN           NaN           NaN        0.0
# 2019-06-24 14:15:00-05:00        NaN           NaN           NaN        0.0
# 2019-06-24 14:00:00-05:00        NaN           NaN           NaN        0.0
# 2019-06-24 14:45:00-05:00        NaN           NaN           NaN        NaN
#
#                            winecooler1    leg1v    leg2v
# local_15min
# 2019-06-24 14:45:00-05:00          NaN  120.625  120.750
# 2019-06-24 14:30:00-05:00          NaN  120.456  120.558
# 2019-06-24 14:15:00-05:00          NaN  120.513  120.629
# 2019-06-24 14:00:00-05:00          NaN  121.567  121.638
# 2019-06-24 14:45:00-05:00          NaN  120.390  120.388
#
# [5 rows x 78 columns]

# %%
df= df_old[df_old['dataid']==914][['grid']]

df.head()
# Out:
#                             grid
# local_15min
# 2019-06-24 14:45:00-05:00 -3.311
# 2019-06-24 14:30:00-05:00 -2.354
# 2019-06-24 14:15:00-05:00 -2.126
# 2019-06-24 14:00:00-05:00 -2.418
# 2019-06-24 15:45:00-05:00 -2.019

# %%
df['New_date'] = pd.to_datetime(df['local_15min']).dt.date
df['New_time'] = pd.to_datetime(df['local_15min']).dt.time
df['Month'] = pd.to_datetime(df['local_15min']).dt.month
df.head(5)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/envs/tensorflow_env/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'local_15min'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-37-c30193f593e3> in <module>
# ----> 1 df['New_date'] = pd.to_datetime(df['local_15min']).dt.date
#       2 df['New_time'] = pd.to_datetime(df['local_15min']).dt.time
#       3 df['Month'] = pd.to_datetime(df['local_15min']).dt.month
#       4 df.head(5)
#
# ~/opt/anaconda3/envs/tensorflow_env/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~/opt/anaconda3/envs/tensorflow_env/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'local_15min'

# %%
#plotting things, taken from https://www.kaggle.com/msripooja/hourly-energy-consumption-time-series-rnn-lstm

#article_read[article_read['dataid']==914][['local_15min','grid']] #filtering, counting the colomns: .isna().sum() 
#.hist() 
#article_read[article_read['dataid']==914]['grid'].plot(figsize=(16,4),legend=True)

#plt.ylabel('Consumption from the grid, kW')

#plt.xlabel('Time')

#plt.title('Power consumption data - 15 min - BEFORE NORMALIZATION')

#plt.show()


df.plot(figsize=(16,4),legend=True)

plt.title('Power consumption data - BEFORE NORMALIZATION')

plt.ylabel('Power consumption, kW')

plt.xlabel('Time')

plt.show()

# %%
df_sol= df_old[df_old['dataid']==914][['solar']]

df_sol.head()
# Out:
#                            solar
# local_15min
# 2019-06-24 14:45:00-05:00  3.831
# 2019-06-24 14:30:00-05:00  2.971
# 2019-06-24 14:15:00-05:00  2.582
# 2019-06-24 14:00:00-05:00  2.783
# 2019-06-24 15:45:00-05:00  2.488

# %%
#article_read[article_read['dataid']==914]['solar'].plot(figsize=(16,4),legend=True)
#plt.title('Solar gerenation data - 15 min - BEFORE NORMALIZATION')
#plt.ylabel('Solar generation, kW')
#plt.xlabel('Time')
#plt.show()
#article_read[article_read['dataid']==914]['grid'].hist()

df_sol.plot(figsize=(16,4),legend=True)

plt.title('Solar gerenation data - BEFORE NORMALIZATION')

plt.ylabel('Solar generation, kW')

plt.xlabel('Time')

plt.show()

# %%
def normalize_data(df):
    scaler = sklearn.preprocessing.MinMaxScaler()
    df_sol['solar']=scaler.fit_transform(df_sol['solar'].values.reshape(-1,1))
    return df

df_sol_norm = normalize_data(df)
df_sol_norm.shape
# Out:
# (17664, 1)

# %%
df_sol_norm.plot(figsize=(16,4),legend=True)

plt.title('Solar gerenation data - AFTER NORMALIZATION')

plt.ylabel('Solar generation, kW')

plt.xlabel('Time')

plt.show()

df_sol_norm.plot(figsize=(16,4),legend=True)
# Out:
# <AxesSubplot:xlabel='local_15min'>

# %%
#Let's use datetime(2012-10-01 12:00:00,...) as index instead of numbers(0,1,...)
#This will be helpful for further data analysis as we are dealing with time series data

df_old= pd.read_csv('fifteen_minute_data_newyork.csv', index_col='local_15min', parse_dates=['local_15min'])

df_old.head()
# Out:
#                            dataid   air1  air2  air3  airwindowunit1  \
# local_15min
# 2019-06-24 14:45:00-05:00    4550    NaN   NaN   NaN             NaN
# 2019-06-24 14:30:00-05:00    4550    NaN   NaN   NaN             NaN
# 2019-06-24 14:15:00-05:00    4550    NaN   NaN   NaN             NaN
# 2019-06-24 14:00:00-05:00    4550    NaN   NaN   NaN             NaN
# 2019-06-24 14:45:00-05:00     558  0.081   NaN   NaN             NaN
#
#                            aquarium1  bathroom1  bathroom2  bedroom1  \
# local_15min
# 2019-06-24 14:45:00-05:00        NaN        NaN        NaN       NaN
# 2019-06-24 14:30:00-05:00        NaN        NaN        NaN       NaN
# 2019-06-24 14:15:00-05:00        NaN        NaN        NaN       NaN
# 2019-06-24 14:00:00-05:00        NaN        NaN        NaN       NaN
# 2019-06-24 14:45:00-05:00        NaN        NaN        NaN       NaN
#
#                            bedroom2  ...  sprinkler1  sumppump1  utilityroom1  \
# local_15min                          ...
# 2019-06-24 14:45:00-05:00       NaN  ...         NaN        NaN           NaN
# 2019-06-24 14:30:00-05:00       NaN  ...         NaN        NaN           NaN
# 2019-06-24 14:15:00-05:00       NaN  ...         NaN        NaN           NaN
# 2019-06-24 14:00:00-05:00       NaN  ...         NaN        NaN           NaN
# 2019-06-24 14:45:00-05:00       NaN  ...         NaN        NaN           NaN
#
#                            venthood1  waterheater1  waterheater2  wellpump1  \
# local_15min
# 2019-06-24 14:45:00-05:00        NaN           NaN           NaN        0.0
# 2019-06-24 14:30:00-05:00        NaN           NaN           NaN        0.0
# 2019-06-24 14:15:00-05:00        NaN           NaN           NaN        0.0
# 2019-06-24 14:00:00-05:00        NaN           NaN           NaN        0.0
# 2019-06-24 14:45:00-05:00        NaN           NaN           NaN        NaN
#
#                            winecooler1    leg1v    leg2v
# local_15min
# 2019-06-24 14:45:00-05:00          NaN  120.625  120.750
# 2019-06-24 14:30:00-05:00          NaN  120.456  120.558
# 2019-06-24 14:15:00-05:00          NaN  120.513  120.629
# 2019-06-24 14:00:00-05:00          NaN  121.567  121.638
# 2019-06-24 14:45:00-05:00          NaN  120.390  120.388
#
# [5 rows x 78 columns]

# %%
#df= df_old[df['dataid']==914]['grid']
#df.head()

df= df_old[df_old['dataid']==914][['grid']]

df.head()
# Out:
#                             grid
# local_15min
# 2019-06-24 14:45:00-05:00 -3.311
# 2019-06-24 14:30:00-05:00 -2.354
# 2019-06-24 14:15:00-05:00 -2.126
# 2019-06-24 14:00:00-05:00 -2.418
# 2019-06-24 15:45:00-05:00 -2.019

# %%
df.head(20) #to see what I am defining
# Out:
#                             grid
# local_15min
# 2019-06-24 14:45:00-05:00 -3.311
# 2019-06-24 14:30:00-05:00 -2.354
# 2019-06-24 14:15:00-05:00 -2.126
# 2019-06-24 14:00:00-05:00 -2.418
# 2019-06-24 15:45:00-05:00 -2.019
# 2019-06-24 15:30:00-05:00 -3.150
# 2019-06-24 15:15:00-05:00 -1.649
# 2019-06-24 15:00:00-05:00 -2.011
# 2019-06-24 16:45:00-05:00 -1.178
# 2019-06-24 16:30:00-05:00 -0.616
# 2019-06-24 16:15:00-05:00 -0.866
# 2019-06-24 16:00:00-05:00 -1.491
# 2019-06-24 17:45:00-05:00  0.828
# 2019-06-24 17:30:00-05:00  2.865
# 2019-06-24 17:15:00-05:00  1.927
# 2019-06-24 17:00:00-05:00  1.270
# 2019-06-29 15:45:00-05:00  2.891
# 2019-06-29 15:30:00-05:00  3.137
# 2019-06-29 15:15:00-05:00  2.576
# 2019-06-29 15:00:00-05:00  0.103

# %%
#soo, here we only normalize 1 column 'grid' in the house number 914
#from sklearn import preprocessing

#x_array = np.array(article_read[article_read['dataid']==914]['grid'])
#normalized_arr = preprocessing.normalize([x_array])

#print(normalized_arr)


#defining dataframe 

#df= article_read[article_read['dataid']==914][['local_15min','grid']] #put 2 columns into the frame definition

#IT WORKS!!!! hey baby hey baby hey boys say, girls say

# %%
#from sklearn import preprocessing
#x_array = np.array(df['grid'])
#normalized_arr = preprocessing.normalize([x_array])
#print(normalized_arr)


def normalize_data(df):
    scaler = sklearn.preprocessing.MinMaxScaler()
    df['grid']=scaler.fit_transform(df['grid'].values.reshape(-1,1))
    return df

df_norm = normalize_data(df)
df_norm.shape
# Out:
# (17664, 1)

# %%
df_norm.plot(figsize=(16,4),legend=True)

plt.title('power consumption data - AFTER NORMALIZATION')

plt.ylabel('Power consumption, kW')

plt.xlabel('Time')

plt.show()

# %%
df_norm.shape
# Out:
# (17664, 1)

# %%
df.shape #see rows number
# Out:
# (17664, 1)

# %% [markdown]
# # Build a SIMPLE RNN model for 1 house

# %%
def load_data(stock, seq_len):
    X_train = []
    y_train = []
    for i in range(seq_len, len(stock)):
        X_train.append(stock.iloc[i-seq_len : i, 0])
        y_train.append(stock.iloc[i, 0])
        
        
     #splitting the data for the test and training 
    
#I CHANGED 1100000 into 110000!!!!!!!
    
    #1 last 6189 days are going to be used in test 
    X_test = X_train[11000:]             
    y_test = y_train[11000:]
    
    #2 first 110000 days are going to be used in training
    X_train = X_train[:11000]           
    y_train = y_train[:11000]
    
    #3 convert to numpy array
    X_train = np.array(X_train)
    y_train = np.array(y_train)
    
    X_test = np.array(X_test)
    y_test = np.array(y_test)
    
    #4 reshape data to input into RNN models
    X_train = np.reshape(X_train, (11000, seq_len, 1))
    
    X_test = np.reshape(X_test, (X_test.shape[0], seq_len, 1))
    
    return [X_train, y_train, X_test, y_test]

# %%
seq_len = 20 #choose sequence length

X_train, y_train, X_test, y_test = load_data(df, seq_len)

print('X_train.shape = ',X_train.shape)
print('y_train.shape = ', y_train.shape)
print('X_test.shape = ', X_test.shape)
print('y_test.shape = ',y_test.shape)
# Out:
# X_train.shape =  (11000, 20, 1)
# y_train.shape =  (11000,)
# X_test.shape =  (6644, 20, 1)
# y_test.shape =  (6644,)

# %%
rnn_model = Sequential()

rnn_model.add(SimpleRNN(40,activation="tanh",return_sequences=True, input_shape=(X_train.shape[1],1)))
rnn_model.add(Dropout(0.15))

rnn_model.add(SimpleRNN(40,activation="tanh",return_sequences=True))
rnn_model.add(Dropout(0.15))

rnn_model.add(SimpleRNN(40,activation="tanh",return_sequences=False))
rnn_model.add(Dropout(0.15))

rnn_model.add(Dense(1))

rnn_model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# simple_rnn_1 (SimpleRNN)     (None, 20, 40)            1680
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 20, 40)            0
# _________________________________________________________________
# simple_rnn_2 (SimpleRNN)     (None, 20, 40)            3240
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 20, 40)            0
# _________________________________________________________________
# simple_rnn_3 (SimpleRNN)     (None, 40)                3240
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 40)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 41
# =================================================================
# Total params: 8,201
# Trainable params: 8,201
# Non-trainable params: 0
# _________________________________________________________________

# %%
#compiling the model with test and training, x is a date, y is consumption 
rnn_model.compile(optimizer="adam",loss="MSE")
rnn_model.fit(X_train, y_train, epochs=10, batch_size=1000) #defining input, the rusult is a framemodel for predictions
# Out:
# Epoch 1/10
# 11000/11000 [==============================] - 10s 888us/step - loss: 0.4311
# Epoch 2/10
# 11000/11000 [==============================] - 4s 323us/step - loss: 0.1831
# Epoch 3/10
# 11000/11000 [==============================] - 4s 321us/step - loss: 0.1491
# Epoch 4/10
# 11000/11000 [==============================] - 4s 324us/step - loss: 0.1265
# Epoch 5/10
# 11000/11000 [==============================] - 4s 344us/step - loss: 0.1102
# Epoch 6/10
# 11000/11000 [==============================] - 4s 328us/step - loss: 0.0967
# Epoch 7/10
# 11000/11000 [==============================] - 4s 333us/step - loss: 0.0841
# Epoch 8/10
# 11000/11000 [==============================] - 4s 324us/step - loss: 0.0761
# Epoch 9/10
# 11000/11000 [==============================] - 4s 325us/step - loss: 0.0675
# Epoch 10/10
# 11000/11000 [==============================] - 4s 350us/step - loss: 0.0622

# %%
rnn_predictions = rnn_model.predict(X_test)

rnn_score = r2_score(y_test,rnn_predictions)
print("R2 Score of RNN model = ",rnn_score)
# Out:
# R2 Score of RNN model =  0.6964241985684976

# %%
def plot_predictions(test, predicted, title):
    plt.figure(figsize=(16,4))
    plt.plot(test, color='blue',label='Actual power consumption data')
    plt.plot(predicted, alpha=0.7, color='red',label='Predicted power consumption data')
    plt.title(title)
    plt.xlabel('Time')
    plt.ylabel('Normalized power consumption scale')
    plt.legend()
    plt.show()
    
plot_predictions(y_test, rnn_predictions, "Predictions made by simple RNN model")

# %% [markdown]
# # Build a SIMPLE LSTM model

# %%
lstm_model = Sequential()

lstm_model.add(LSTM(40,activation="tanh",return_sequences=True, input_shape=(X_train.shape[1],1)))
lstm_model.add(Dropout(0.15))

lstm_model.add(LSTM(40,activation="tanh",return_sequences=True))
lstm_model.add(Dropout(0.15))

lstm_model.add(LSTM(40,activation="tanh",return_sequences=False))
lstm_model.add(Dropout(0.15))

lstm_model.add(Dense(1))

lstm_model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 20, 40)            6720
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 20, 40)            0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 20, 40)            12960
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 20, 40)            0
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 40)                12960
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 40)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 41
# =================================================================
# Total params: 32,681
# Trainable params: 32,681
# Non-trainable params: 0
# _________________________________________________________________

# %%
lstm_model.compile(optimizer="adam",loss="MSE")
lstm_model.fit(X_train, y_train, epochs=10, batch_size=1000)
# Out:
# Epoch 1/10
# 11000/11000 [==============================] - 23s 2ms/step - loss: 0.1254
# Epoch 2/10
# 11000/11000 [==============================] - 14s 1ms/step - loss: 0.0330
# Epoch 3/10
# 11000/11000 [==============================] - 14s 1ms/step - loss: 0.0247
# Epoch 4/10
# 11000/11000 [==============================] - 14s 1ms/step - loss: 0.0215
# Epoch 5/10
# 11000/11000 [==============================] - 14s 1ms/step - loss: 0.0204
# Epoch 6/10
# 11000/11000 [==============================] - 14s 1ms/step - loss: 0.0197
# Epoch 7/10
# 11000/11000 [==============================] - 14s 1ms/step - loss: 0.0189
# Epoch 8/10
# 11000/11000 [==============================] - 14s 1ms/step - loss: 0.0183
# Epoch 9/10
# 11000/11000 [==============================] - 16s 1ms/step - loss: 0.0179
# Epoch 10/10
# 11000/11000 [==============================] - 16s 1ms/step - loss: 0.0175

# %%
lstm_predictions = lstm_model.predict(X_test)

lstm_score = r2_score(y_test, lstm_predictions)
print("R^2 Score of LSTM model = ",lstm_score)
# Out:
# R^2 Score of LSTM model =  0.40399409215225934

# %%
plot_predictions(y_test, lstm_predictions, "Predictions made by LSTM model")

# %% [markdown]
# # metadata.csv and 15_min_NY_data.csv (25 houses) analysis
#
# houses with cars from metadata:  1222,  3000,  3976,  9973, 11435,  9053,  6178,  5679,    27,
#         3517,   518,  5058,  2126, 10202,  8577
#
# all houses in NY: 4550,  558, 2358, 3700, 1417, 5679, 5058, 2318, 5997,  950, 5982,
#        5587, 1222,  387, 3000, 4283, 3488, 3517, 9053, 3996,   27,  142,
#         914, 2096, 1240
#
# houses with cars in NY: 27, 1222, 3000, 9053, 5679, 3517, 5058,

# %%
article_read['dataid'].unique() #Valeria create a loop to check if the houses have cars, generations, batteries
# Out:
# array([4550,  558, 2358, 3700, 1417, 5679, 5058, 2318, 5997,  950, 5982,
#        5587, 1222,  387, 3000, 4283, 3488, 3517, 9053, 3996,   27,  142,
#         914, 2096, 1240])

# %%
one_house_NY= article_read[(article_read['dataid']==27)][['grid', 'local_15min', 'solar', 'car1']]

one_house_NY.head()
# Out:
#       grid             local_15min  solar   car1
# 80  -4.386  2019-06-29 14:45:00-05  4.895  0.003
# 81  -3.609  2019-06-29 14:30:00-05  4.163  0.003
# 82  -7.870  2019-06-29 14:15:00-05  8.433  0.003
# 83  -2.431  2019-06-29 14:00:00-05  3.083  0.003
# 104 -0.699  2019-06-24 14:45:00-05  4.565  3.380

# %%
#1
one_house_NY['grid'].plot(figsize=(16,4),legend=True)

plt.title('power consumption data')

plt.ylabel('Power consumption, kW')

plt.xlabel('Time')

plt.show()

#2

one_house_NY['car1'].plot(figsize=(16,4),legend=True)

plt.title('Electric vehicle consumption')

plt.ylabel('Power consumption, kW')

plt.xlabel('Time')
plt.show()

#3
one_house_NY['solar'].plot(figsize=(16,4),legend=True)

plt.title('solar generation')

plt.ylabel('generation, kW')

plt.xlabel('Time')
plt.show()

# %%
#sns.scatterplot(data=one_house_NY, x="local_15min", y="grid")

#sns.set(rc={'figure.figsize': (11, 4)})
#solar_plot = days['grid_kwh'].plot(linewidth=0.5, marker='.')
#solar_plot.set_xlabel('Date')
#solar_plot.set_ylabel('Grid Usage kWh')
#solar_plot.set_title('Average Grid Usage in Austin, TX')

# display the plot

#plt.show()

# %%
df_meta= pd.read_csv('metadata.csv', skiprows=[1])

df_meta.head()
# Out:
#    dataid active_record                    building_type    city  state  \
# 0    2836           NaN  Single-Family Home 001 (Master)  Austin  Texas
# 1    2743           NaN  Single-Family Home 001 (Master)  Austin  Texas
# 2    5323           NaN  Single-Family Home 001 (Master)  Austin  Texas
# 3    8560           NaN  Single-Family Home 001 (Master)  Austin  Texas
# 4    3313           NaN  Single-Family Home 001 (Master)  Austin  Texas
#
#   egauge_1min_min_time egauge_1min_max_time egauge_1min_data_availability  \
# 0                  NaN                  NaN                           NaN
# 1                  NaN                  NaN                           NaN
# 2                  NaN                  NaN                           NaN
# 3                  NaN                  NaN                           NaN
# 4                  NaN                  NaN                           NaN
#
#   egauge_1s_min_time egauge_1s_max_time  ... survey_2017 survey_2019  \
# 0                NaN                NaN  ...         NaN         NaN
# 1                NaN                NaN  ...         NaN         NaN
# 2                NaN                NaN  ...         NaN         NaN
# 3                NaN                NaN  ...         NaN         NaN
# 4                NaN                NaN  ...         NaN         NaN
#
#   program_579 program_baseline program_energy_internet_demo  \
# 0         NaN              NaN                          yes
# 1         NaN              NaN                          yes
# 2         NaN              yes                          yes
# 3         NaN              yes                          yes
# 4         NaN              yes                          yes
#
#   program_lg_appliance program_verizon program_ccet_group  \
# 0                  NaN             NaN                NaN
# 1                  NaN             NaN                NaN
# 2                  NaN             NaN                NaN
# 3                  NaN             NaN                NaN
# 4                  NaN             NaN                NaN
#
#   program_civita_group program_shines
# 0                  NaN            NaN
# 1                  NaN            NaN
# 2                  NaN            NaN
# 3                  NaN            NaN
# 4                  NaN            NaN
#
# [5 rows x 127 columns]

# %% [markdown]
# # #Как выбрать строки из Pandas DataFrame по условию
# **df.loc[df.column name condition]**
#
# OR
# df_state = df_meta ['state']. isin (['New York'])
# df_meta[df_state]

# %%
NY = df_meta.loc[(df_meta.state == 'New York')& 
                 (df_meta.active_record == 'yes')&
                 (df_meta.car1 == 'yes')]
#NY = df_meta.loc[df_meta.state == 'New York']
NY.head()
# Out:
#      dataid active_record                    building_type    city     state  \
# 62     1222           yes  Single-Family Home 001 (Master)  Ithaca  New York
# 66     3000           yes  Single-Family Home 001 (Master)  Ithaca  New York
# 74     3976           yes  Single-Family Home 001 (Master)  Ithaca  New York
# 105    9973           yes  Single-Family Home 001 (Master)  Ithaca  New York
# 109   11435           yes  Single-Family Home 001 (Master)  Dryden  New York
#
#           egauge_1min_min_time       egauge_1min_max_time  \
# 62   2019-04-17 19:00:00-05:00  2021-01-31 02:59:00-06:00
# 66   2019-03-11 19:00:00-05:00  2021-01-31 02:59:00-06:00
# 74   2019-04-02 19:00:00-05:00  2020-09-05 10:59:00-05:00
# 105  2019-02-21 13:00:00-06:00  2021-01-31 02:59:00-06:00
# 109  2019-10-09 19:00:00-05:00  2019-12-07 06:59:00-06:00
#
#     egauge_1min_data_availability         egauge_1s_min_time  \
# 62                           100%  2019-04-17 19:00:00-05:00
# 66                           100%  2019-03-11 19:00:00-05:00
# 74                            99%  2019-04-02 19:00:00-05:00
# 105                           86%  2019-02-21 14:00:00-06:00
# 109                           99%  2019-10-09 19:00:00-05:00
#
#             egauge_1s_max_time  ... survey_2017 survey_2019 program_579  \
# 62   2021-01-31 00:00:00-06:00  ...         NaN         yes         NaN
# 66   2021-01-31 02:00:00-06:00  ...         NaN         NaN         NaN
# 74   2020-09-05 09:00:00-05:00  ...         NaN         yes         NaN
# 105  2021-01-31 02:00:00-06:00  ...         NaN         NaN         NaN
# 109  2019-12-07 06:00:00-06:00  ...         NaN         NaN         NaN
#
#     program_baseline program_energy_internet_demo program_lg_appliance  \
# 62               NaN                          NaN                  NaN
# 66               NaN                          NaN                  NaN
# 74               NaN                          NaN                  NaN
# 105              NaN                          NaN                  NaN
# 109              NaN                          NaN                  NaN
#
#     program_verizon program_ccet_group program_civita_group program_shines
# 62              NaN                NaN                  NaN            NaN
# 66              NaN                NaN                  NaN            NaN
# 74              NaN                NaN                  NaN            NaN
# 105             NaN                NaN                  NaN            NaN
# 109             NaN                NaN                  NaN            NaN
#
# [5 rows x 127 columns]

# %%
NY.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15 entries, 62 to 1603
# Columns: 127 entries, dataid to program_shines
# dtypes: float64(12), int64(1), object(114)
# memory usage: 15.0+ KB

# %%
NY['city'].unique()
# Out:
# array(['Ithaca', 'Dryden', 'Lansing', 'Brooktondale', 'Trumansburg'],
#       dtype=object)

# %%
NY['car1'].value_counts()
# Out:
# yes    15
# Name: car1, dtype: int64

# %%
NY['car2'].value_counts()
# Out:
# yes    1
# Name: car2, dtype: int64

# %%
NY['solar'].value_counts()
# Out:
# yes    64
# Name: solar, dtype: int64

# %%
NY['solar2'].value_counts()
# Out:
# yes    6
# Name: solar2, dtype: int64

# %%
NY['dataid'].unique()
# Out:
# array([ 1222,  3000,  3976,  9973, 11435,  9053,  6178,  5679,    27,
#         3517,   518,  5058,  2126, 10202,  8577])

# %%
NY['active_record'].value_counts()
# Out:
# yes    115
# Name: active_record, dtype: int64

# %%
cars_counts = df_meta['city'].value_counts()

cars_counts[:10].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
one_house= NY[NY['dataid']==914]

one_house.head()
# Out:
#      dataid active_record                    building_type    city     state  \
# 127     914           yes  Single-Family Home 001 (Master)  Ithaca  New York
#
#           egauge_1min_min_time       egauge_1min_max_time  \
# 127  2019-02-15 18:00:00-06:00  2021-01-31 02:59:00-06:00
#
#     egauge_1min_data_availability         egauge_1s_min_time  \
# 127                           68%  2019-02-15 18:00:00-06:00
#
#             egauge_1s_max_time  ... survey_2017 survey_2019 program_579  \
# 127  2021-01-31 01:00:00-06:00  ...         NaN         yes         NaN
#
#     program_baseline program_energy_internet_demo program_lg_appliance  \
# 127              NaN                          NaN                  NaN
#
#     program_verizon program_ccet_group program_civita_group program_shines
# 127             NaN                NaN                  NaN            NaN
#
# [1 rows x 127 columns]

# %%
article_read.grid.sum() #sums up all values in grid
# Out:
# 128070.65300000003

# %%
article_read.grid.min()
# Out:
# -16.831

# %%
article_read.grid.max()
# Out:
# 20.955

# %%
article_read.grid.mean()
# Out:
# 0.2900157224087917

# %%
article_read.grid.median()
# Out:
# 0.436

# %%
article_read.groupby('grid').mean()
article_read.groupby('grid').count()[['dataid']] # keep only 1 colomn
# Out:
#          dataid
# grid
# -16.831       1
# -16.524       1
# -16.515       1
# -16.498       1
# -16.415       1
# ...         ...
#  14.257       1
#  15.748       1
#  16.659       1
#  17.461       1
#  20.955       1
#
# [16812 rows x 1 columns]

# %% [markdown]
# # METADATA taken from https://github.com/Pecan-Street/DataPort-Examples
#
# change it to New York

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# This constant limits the number of rows read in from the big CSV file.
# Set to None if you want to read the whole thing
LIMIT = None

if not os.path.isfile('metadata.csv'):
    print("Could not find metadata.csv file in {} .".format(os.getcwd()))
    exit(1)
if not os.path.isfile('15minute_data_austin.csv'):
    print("Could not find 15minute_data_austin.csv file in {} .".format(os.getcwd()))
    exit(1)

# read in the metadata file, skip the 2nd row because it has the comments further describing the headers
metadata = pd.read_csv('metadata.csv', engine='python', encoding="ISO-8859-1", skiprows=[1])


# filter down to our houses of interest. Active, Austin-based, has complete data, and has the grid circuit
dataids = metadata[metadata.active_record.eq('yes') &
                   metadata.city.eq('Austin') &
                   metadata.egauge_1min_data_availability.isin(['100%', '99%', '98%', '97%']) &
                   metadata.grid.eq('yes')]


# read the 15 minute data file for Austin
all_data = pd.read_csv('15minute_data_austin.csv', engine='python', encoding="ISO-8859-1",
                                  parse_dates=['local_15min'], index_col=['local_15min'],
                                  usecols=['dataid', 'local_15min', 'grid'],
                                  nrows=LIMIT)

# filter down to the dataids we're interested in
filt = all_data[all_data.dataid.isin(dataids.dataid)]

filt.index = pd.to_datetime(filt.index, utc=True, infer_datetime_format=True)
filt = filt.tz_convert('US/Central')

print(filt.describe())

# group the data by days and take the mean of those
days = filt.groupby(pd.Grouper(freq='D')).mean()

# convert from kW to kWh
days['grid_kwh'] = days['grid'].apply(lambda x: x * 24)

print(days.describe())

# create the plot
# Use seaborn style defaults and set the default figure size
sns.set(rc={'figure.figsize': (11, 4)})
solar_plot = days['grid_kwh'].plot(linewidth=0.5, marker='.')
solar_plot.set_xlabel('Date')
solar_plot.set_ylabel('Grid Usage kWh')
solar_plot.set_title('Average Grid Usage in Austin, TX')

# display the plot
plt.show()

print('done')
exit(0)
# Out:
#               dataid           grid
# count  558839.000000  556165.000000
# mean     5305.848506       0.841128
# std      2810.143155       1.669599
# min       661.000000      -7.650000
# 25%      3039.000000       0.274000
# 50%      5746.000000       0.588000
# 75%      7951.000000       1.437000
# max      9922.000000      15.522000
#             dataid        grid    grid_kwh
# count   365.000000  365.000000  365.000000
# mean   5306.636214    0.842069   20.209660
# std      52.200008    0.526361   12.632675
# min    5195.804348   -0.136730   -3.281516
# 25%    5300.937500    0.387246    9.293906
# 50%    5300.937500    0.796572   19.117719
# 75%    5300.937500    1.259121   30.218906
# max    5867.442724    2.284069   54.817658
# done

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# This constant limits the number of rows read in from the big CSV file.
# Set to None if you want to read the whole thing
LIMIT = None

if not os.path.isfile('metadata.csv'):
    print("Could not find metadata.csv file in {} .".format(os.getcwd()))
    exit(1)
if not os.path.isfile('fifteen_minute_data_newyork.csv'):
    print("Could not find fifteen_minute_data_newyork.csv file in {} .".format(os.getcwd()))
    exit(1)

# read in the metadata file, skip the 2nd row because it has the comments further describing the headers
metadata = pd.read_csv('metadata.csv', engine='python', encoding="ISO-8859-1", skiprows=[1])


# filter down to our houses of interest. Active, Austin-based, has complete data, and has the grid circuit
dataids = metadata[metadata.active_record.eq('yes') &
                   metadata.city.eq('New York') &
                   metadata.egauge_1min_data_availability.isin(['100%', '99%', '98%', '97%']) &
                   metadata.grid.eq('yes')]


# read the 15 minute data file for Austin
all_data = pd.read_csv('fifteen_minute_data_newyork.csv', engine='python', encoding="ISO-8859-1",
                                  parse_dates=['local_15min'], index_col=['local_15min'],
                                  usecols=['dataid', 'local_15min', 'grid'],
                                  nrows=LIMIT)

# filter down to the dataids we're interested in
filt = all_data[all_data.dataid.isin(dataids.dataid)]

filt.index = pd.to_datetime(filt.index, utc=True, infer_datetime_format=True)
filt = filt.tz_convert('US/Central')

print(filt.describe())

# group the data by days and take the mean of those
days = filt.groupby(pd.Grouper(freq='D')).mean()

# convert from kW to kWh
days['grid_kwh'] = days['grid'].apply(lambda x: x * 24)

print(days.describe())

# create the plot
# Use seaborn style defaults and set the default figure size
sns.set(rc={'figure.figsize': (11, 4)})
solar_plot = days['grid_kwh'].plot(linewidth=0.5, marker='.')
solar_plot.set_xlabel('Date')
solar_plot.set_ylabel('Grid Usage kWh')
solar_plot.set_title('Average Grid Usage in Austin, TX')

# display the plot
plt.show()

print('done')
exit(0)
# Out:
#        dataid  grid
# count     0.0   0.0
# mean      NaN   NaN
# std       NaN   NaN
# min       NaN   NaN
# 25%       NaN   NaN
# 50%       NaN   NaN
# 75%       NaN   NaN
# max       NaN   NaN
#        dataid  grid  grid_kwh
# count     0.0   0.0       0.0
# mean      NaN   NaN       NaN
# std       NaN   NaN       NaN
# min       NaN   NaN       NaN
# 25%       NaN   NaN       NaN
# 50%       NaN   NaN       NaN
# 75%       NaN   NaN       NaN
# max       NaN   NaN       NaN
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-233-6611c27e4eff> in <module>
#      51 # Use seaborn style defaults and set the default figure size
#      52 sns.set(rc={'figure.figsize': (11, 4)})
# ---> 53 solar_plot = days['grid_kwh'].plot(linewidth=0.5, marker='.')
#      54 solar_plot.set_xlabel('Date')
#      55 solar_plot.set_ylabel('Grid Usage kWh')
#
# ~/opt/anaconda3/envs/tensorflow_env/lib/python3.6/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     947                     data.columns = label_name
#     948
# --> 949         return plot_backend.plot(data, kind=kind, **kwargs)
#     950
#     951     __call__.__doc__ = __doc__
#
# ~/opt/anaconda3/envs/tensorflow_env/lib/python3.6/site-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
#      63     return plot_obj.result
#
# ~/opt/anaconda3/envs/tensorflow_env/lib/python3.6/site-packages/pandas/plotting/_matplotlib/core.py in generate(self)
#     269         self._compute_plot_data()
#     270         self._setup_subplots()
# --> 271         self._make_plot()
#     272         self._add_table()
#     273         self._make_legend()
#
# ~/opt/anaconda3/envs/tensorflow_env/lib/python3.6/site-packages/pandas/plotting/_matplotlib/core.py in _make_plot(self)
#    1133                 # TODO: GH28021, should find a way to change view limit on xaxis
#    1134                 lines = _get_all_lines(ax)
# -> 1135                 left, right = _get_xlim(lines)
#    1136                 ax.set_xlim(left, right)
#    1137
#
# ~/opt/anaconda3/envs/tensorflow_env/lib/python3.6/site-packages/pandas/plotting/_matplotlib/tools.py in _get_xlim(lines)
#     374     for l in lines:
#     375         x = l.get_xdata(orig=False)
# --> 376         left = min(np.nanmin(x), left)
#     377         right = max(np.nanmax(x), right)
#     378     return left, right
#
# <__array_function__ internals> in nanmin(*args, **kwargs)
#
# ~/opt/anaconda3/envs/tensorflow_env/lib/python3.6/site-packages/numpy/lib/nanfunctions.py in nanmin(a, axis, out, keepdims)
#     317         # Fast, but not safe for subclasses of ndarray, or object arrays,
#     318         # which do not implement isnan (gh-9009), or fmin correctly (gh-8975)
# --> 319         res = np.fmin.reduce(a, axis=axis, out=out, **kwargs)
#     320         if np.isnan(res).any():
#     321             warnings.warn("All-NaN slice encountered", RuntimeWarning,
#
# ValueError: zero-size array to reduction operation fmin which has no identity
